# %% [markdown]
# <a href="https://colab.research.google.com/github/Roberta-Ukaga/Google_Colab/blob/main/Importing_And_Reading_JSON_Files_With_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing and reading JSON files using Python**

# %%
import pandas as pd
json_data = pd.read_json("Jay (1).json")
json_data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#Add a column
json_data["Speed_Rate"] = 150
print(json_data)
# Out:
#      Duration  Pulse  Maxpulse  Calories  Speed_Rate
# 0          60    110       130     409.1         150
# 1          60    117       145     479.0         150
# 2          60    103       135     340.0         150
# 3          45    109       175     282.4         150
# 4          45    117       148     406.0         150
# ..        ...    ...       ...       ...         ...
# 164        60    105       140     290.8         150
# 165        60    110       145     300.4         150
# 166        60    115       145     310.2         150
# 167        75    120       150     320.4         150
# 168        75    125       150     330.4         150
#
# [169 rows x 5 columns]

# %%
json_data.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories  Speed_Rate
# count  169.000000  169.000000  169.000000   164.000000       169.0
# mean    63.846154  107.461538  134.047337   375.800000       150.0
# std     42.299949   14.510259   16.450434   266.377134         0.0
# min     15.000000   80.000000  100.000000    50.300000       150.0
# 25%     45.000000  100.000000  124.000000   250.925000       150.0
# 50%     60.000000  105.000000  131.000000   318.600000       150.0
# 75%     60.000000  111.000000  141.000000   387.600000       150.0
# max    300.000000  159.000000  184.000000  1860.400000       150.0

# %%
json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Duration    169 non-null    int64
#  1   Pulse       169 non-null    int64
#  2   Maxpulse    169 non-null    int64
#  3   Calories    164 non-null    float64
#  4   Speed_Rate  169 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 7.9 KB

# %%
json_data.to_json("Jay1.json")
